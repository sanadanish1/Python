# %% [markdown]
# **List**
#
# List is a data structure in which we can store positionally ordered collection of arbitrary object types like integer, float, string etc.
#
# - It has mutable nature
# - It has no fixed size
# - Duplicates are allowed
#
#
# **Syntax**
#
# list_name=[Item 1, Item 2, ..., Item n]

# %%
import numpy as np
x = np.linspace(10, 15, 5)
print(x)
# Out:
# [10.   11.25 12.5  13.75 15.  ]

# %%
#create empty list
list1=[]
print(type(list1))
print(list1)


#list using list function
list2=list()
print(type(list2))
# Out:
# <class 'list'>
# []
# <class 'list'>

# %%
#create a list and print it
list_1=['alpha', 'beta', 'gamma']
print(list_1)
# Out:
# ['alpha', 'beta', 'gamma']

# %% [markdown]
# **Operations on list**

# %% [markdown]
# **Find length of the list**

# %%
#find length of list
print(len(list_1))
# Out:
# 3

# %%
data1=(1,23,13,17)
print(len(data1))
# Out:
# 4

# %% [markdown]
# **Add element to the list**

# %%
#method 1: "append" automatically adds at last position (you can append another list to this list)
#list_1.append(["a", "b"])

#method 2: add element at specific index
list_1.append("mu")
#list_1.insert(2, "mu")

print(list_1)
# Out:
# ['alpha', 'beta', 'mu', 'gamma', 'mu']

# %% [markdown]
# **Replace the element**

# %%
list_1[1]=15
print(list_1)
# Out:
# ['alpha', 15, 'mu', 'gamma', 'mu']

# %% [markdown]
# **To count how many times a specific item is present**

# %%
print(list_1.count("mu"))
# Out:
# 2

# %% [markdown]
# **To undo append or delete element**
#
# pop:pop modifies the list and returns the element that was removed
#
#
# #If you don’t provide an index, it deletes and returns the last element

# %%
#method 1: to del with item name
#list_1.remove("mu")

#method 2: del by index
#del list_1[-1]

#method 3: delete last element or at specific index
list_1.pop()
#list_1.pop(1)

print(list_1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 8
#       1 #method 1: to del with item name
#       2 #list_1.remove("mu")
#       3
#    (...)
#       6
#       7 #method 3: delete last element or at specific index
# ----> 8 list_1.pop()
#       9 #list_1.pop(1)
#      11 print(list_1)
#
# IndexError: pop from empty list

# %% [markdown]
# **To find index of specific element**

# %%
#list_1.index('beta')
#call item by index
print(list_1[1])
# Out:
# beta

# %% [markdown]
# **To arrange items**

# %%
#arrange in ascending order
list_1=['alpha', 'beta', 'gamma']
#list_1.sort()

#to arrange in descending or reverse order
list_1.sort(reverse=True)
print(list_1)
# Out:
# ['gamma', 'beta', 'alpha']

# %% [markdown]
# **slicing specific region inside list**

# %%
#from index 3 to 5
#list_1[3:6]

#from index 2 to last element
list_1[2:]

#from start to index 3
#list_1[:4]
# Out:
# []

# %% [markdown]
# **cancatenating two or more lists**

# %%
list_2=[2, 3, 4, 6]
list_2+list_1

#OR 
#list_1 + [3,4,9]
# Out:
# [2, 3, 4, 6, 'gamma', 'beta', 'alpha']

# %% [markdown]
# **to check if specific element exist in list or not**

# %%
'a' in list_2
# Out:
# False

# %%
t = ['a', 'b', 'c', 'd', 'e', 'f']
t[1:2] = ['x', 'y', 'z', 1]
print(t)
# Out:
# ['a', 'x', 'y', 'z', 1, 'c', 'd', 'e', 'f']
